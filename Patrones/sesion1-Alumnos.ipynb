# %% [markdown]
# # Reconocimiento estadístico de patrones
# ## Procesamiento de imágenes

# %%
#Cargar librerias
library(jpeg)
library(rgl)
library(grid)
library(stats)
library(kernlab)
set.seed(3)

# %% [markdown]
# ### 1 . Leer y visualizar una imagen

# %%
#Leer imagen
img<-readJPEG("dog.jpg")
imgGray<-0.3*img[,,1]+0.59*img[,,2]+0.11*img[,,3]
#Transformar la imagen
imgGray <- t(apply(imgGray, 2, rev))
# Visualizar
image(imgGray,col=gray((0:255)/255))
# Out:
# plot without title

# %% [markdown]
# ## 1. Visualización de pixeles

# %% [markdown]
# ### Podemos visualizar los pixeles de la imagen a color como puntos en 3D, donde cada dimensión corresponde a un canal.

# %%
open3d() 
x <- img[,,1]
y <- img[,,2]
z <- img[,,3] 
plot3d(x, y, z, col='blue')

# %%
rgl.close()

# %% [markdown]
# ### 1.1. Haz un histograma de la imagen en blanco y negro y agrega una estimación no paramétrica de la densidad.

# %% [markdown]
# ### 1.2. Toma un renglón de la imagen en blanco y negro, $X_i$,  visualiza $X_{i,j}$ contra $X_{i, j+1}$

# %% [markdown]
# ### Plus: visualiza $X_{i,j}$ contra $X_{i, j+ k}$ con $k = 1,2,3,4$. ¿Qué observas?

# %% [markdown]
# ### 1.3 Agrega ruido gaussiano a la imagen y visualiza los resultados. Calcula la entropia de la imagen original y la imagen modificada.

# %% [markdown]
# ## 2. Segmentación usando k medias

# %% [markdown]
# ### Una manera de segmentar una imagen en k diferentes niveles de griz consiste en utilizar el algoritmo k-medias y cambiar el nivel de gris en un pixel por el nivel de gris del centroide del cluster al cual pertenece.

# %%
n<-ncol(imgGray)
##Ejemplo de segmentacion usando k-medias
#Show image for k in {2,3,4,5}
par(mfrow = c(2,2))
for (k in 2:5){
    km<-kmeans(as.vector(imgGray), k)
    cluster<-km$cluster
    for (l in 1:k){
        cluster<-replace(cluster, cluster == l, km$centers[l])
    }
    centerValM<-matrix(cluster, n, n)
    image(centerValM,col=gray((0:255)/255))
}
# Out:
# plot without title

# %% [markdown]
# ### 2.1 ¿Cómo determinar el número de grupos?

# %%
wss <- rep(0, 6)
wss[1] <- (n*n - 1) * sum(var(as.vector(imgGray)))
for (i in 2:6){
    wss[i] <- sum(kmeans(as.vector(imgGray),centers = i)$withinss)
}
plot(1:6, wss, type = "b", xlab = "Numero de grupos",
ylab = "Suma de cuadrados entre grupos")
# Out:
# plot without title

# %% [markdown]
# ### 2.2. ¿Cómo utilizarías esta técnica para imágenes a color?

# %%
grid.raster(img)
data<-cbind(as.vector(img[,,1]),as.vector(img[,,2]),as.vector(img[,,3]))
# Out:
# plot without title

# %%
wss <- rep(0, 6)
wss[1] <- (n*n - 1) * sum(var(as.vector(img)))
for (i in 2:6){
    wss[i] <- sum(kmeans(as.vector(img),centers = i)$withinss)
}
plot(1:6, wss, type = "b", xlab = "Numero de grupos",
ylab = "Suma de cuadrados entre grupos")
# Out:
# plot without title

# %%
#img <-t(apply(img, 2, rev))
n<-ncol(data)
##Ejemplo de segmentacion usando k-medias
#Show image for k in {2,3,4,5}
par(mfrow = c(2,2))
for (k in 2:5){
    km<-kmeans(data, k)
    clusterR<-km$cluster
    clusterG<-km$cluster
    clusterB<-km$cluster
    for (l in 1:k){
        clusterR<-replace(clusterR, cluster == l, km$centers[l, 1])
        clusterG<-replace(clusterG, cluster == l, km$centers[l, 2])
        clusterB<-replace(clusterB, cluster == l, km$centers[l, 3])
    }
    centerValM<-matrix(cluster, n, n)
    image(centerValM)
}
# Out:
# plot without title

# %% [markdown]
# ## 3. Compresión de imágenes

# %% [markdown]
# ### 3.1 Compresión usando SVD

# %%
#Hacemos SVD de la imagen en blanco y negro
svdImg<-svd(imgGray)
d <- svdImg$d
u <- svdImg$u
v <- svdImg$v
par(mfrow = c(2,2))
#Hacemos la reconstruccion utilizando i valores propios  vectores propios
for (i in seq(10,70,20)){
    compressedImg<- u[,1:i] %*% diag(d[1:i]) %*% t(v[,1:i])
    image(compressedImg, col = gray((0:255)/255), main = i)
}
# Out:
# Plot with title “70”

# %% [markdown]
# ### 3.2. Compresión usando PCA
# ### Consiste en dividir la imagen en bloques de cxc pixeles. Con los valores de cada bloque se forma un vector y se agrupan en una matriz de datos. La compresión consiste en proyectar los datos sobre los primeros k componentes principales. La decompresión consiste en reconstruir los datos a partir de estas proyecciones.

# %%
#FUNCIONES AUXILIARES
# Divide la una imagen en bloques de cxc
mat_split <- function(M, c){
    sizeCol <-ncol(M)/c
    sizeRow <-nrow(M)/c
    splitByCol<-lapply(1:c, function(x) {M[, ((x-1)*(sizeCol)+1):(x*sizeCol)]})
    splitByColRow<-lapply(splitByCol, function(mat){
        lapply(1:c, function(x) {
            mat[((x-1)*(sizeRow)+1):(x*sizeRow), ]
        })
    })
    return(splitByColRow)
}


#Recibe una lista de matrices y devuelve una lista de vectores
unrollMatrices<-function(matList){
    lapply(1:length(matList), function(y) {
        lapply(1:length(matList[[y]]), function(x) {c(t(matList[[y]][[x]]))})	
    })
}

#Recibe una lista de vectores y devuelve una matriz
vecsToMat<-function(vecList){
    res<-matrix(unlist(vecList), byrow = TRUE, ncol=length(vecList[[1]][[1]]))
    return(res)
}

#Reconstrucción de la imagen
#Recibe una matriz de componentes y devuelve la matriz con la imagen
matToImage<-function(matrixC){
    c<-sqrt(ncol(matrixC))
    imageList<-lapply(1:nrow(matrixC), function(x) {matrix(matrixC[x,], byrow=TRUE, ncol = c)})
    nImages<-sqrt(length(imageList))
    matImg<-lapply(0:(nImages-1), function(y) {
            do.call(rbind, imageList[seq(nImages*y+1, nImages*(y+1))])
    })
    res<-do.call(cbind, matImg)
    return(res)
}

# %% [markdown]
# ### Realiza la compresión de la imágen usando el procedimiento mencionado anteriormente. Puedes usar las funciones auxiliares

# %%
cxc <- mat_split(imgGray, 10)

# %%
unrolled <- unrollMatrices(cxc)
d <-vecsToMat(unrolled)
sc <- scale(d)
svds <- prcomp(sc)

# %%
summary(svds)
# Out:
# Importance of components:
#                            PC1      PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     36.5115 14.22724 9.35280 8.12738 6.51283 6.38286 5.53815
# Proportion of Variance  0.5786  0.08785 0.03797 0.02867 0.01841 0.01768 0.01331
# Cumulative Proportion   0.5786  0.66645 0.70442 0.73309 0.75150 0.76918 0.78249
#                           PC8     PC9    PC10    PC11    PC12   PC13    PC14
# Standard deviation     5.2576 4.99396 4.53958 4.33972 4.12738 4.0443 3.93932
# Proportion of Variance 0.0120 0.01082 0.00894 0.00817 0.00739 0.0071 0.00674
# Cumulative Proportion  0.7945 0.80531 0.81426 0.82243 0.82983 0.8369 0.84366
#                           PC15    PC16    PC17    PC18    PC19    PC20    PC21
# Standard deviation     3.77215 3.72668 3.69593 3.54544 3.47003 3.33805 3.31800
# Proportion of Variance 0.00618 0.00603 0.00593 0.00546 0.00523 0.00484 0.00478
# Cumulative Proportion  0.84984 0.85586 0.86179 0.86725 0.87248 0.87731 0.88209
#                           PC22    PC23    PC24   PC25    PC26    PC27    PC28
# Standard deviation     3.17673 3.16218 3.15104 3.1121 3.01515 2.94269 2.89068
# Proportion of Variance 0.00438 0.00434 0.00431 0.0042 0.00395 0.00376 0.00363
# Cumulative Proportion  0.88647 0.89081 0.89512 0.8993 0.90327 0.90703 0.91065
#                           PC29    PC30    PC31    PC32    PC33    PC34    PC35
# Standard deviation     2.80823 2.79534 2.73796 2.66289 2.56423 2.54223 2.49955
# Proportion of Variance 0.00342 0.00339 0.00325 0.00308 0.00285 0.00281 0.00271
# Cumulative Proportion  0.91408 0.91747 0.92072 0.92380 0.92665 0.92946 0.93217
#                           PC36    PC37    PC38    PC39    PC40   PC41    PC42
# Standard deviation     2.48959 2.43830 2.42582 2.38437 2.33505 2.3016 2.27182
# Proportion of Variance 0.00269 0.00258 0.00255 0.00247 0.00237 0.0023 0.00224
# Cumulative Proportion  0.93486 0.93744 0.93999 0.94246 0.94483 0.9471 0.94937
#                           PC43   PC44    PC45    PC46    PC47    PC48   PC49
# Standard deviation     2.21959 2.2006 2.18907 2.10668 2.05380 2.01090 1.9782
# Proportion of Variance 0.00214 0.0021 0.00208 0.00193 0.00183 0.00176 0.0017
# Cumulative Proportion  0.95151 0.9536 0.95569 0.95761 0.95945 0.96120 0.9629
#                           PC50    PC51    PC52    PC53    PC54    PC55   PC56
# Standard deviation     1.96497 1.92371 1.87288 1.84869 1.81023 1.78879 1.7301
# Proportion of Variance 0.00168 0.00161 0.00152 0.00148 0.00142 0.00139 0.0013
# Cumulative Proportion  0.96457 0.96618 0.96770 0.96919 0.97061 0.97200 0.9733
#                           PC57    PC58    PC59    PC60    PC61    PC62    PC63
# Standard deviation     1.68730 1.65681 1.63326 1.61364 1.57557 1.54690 1.52526
# Proportion of Variance 0.00124 0.00119 0.00116 0.00113 0.00108 0.00104 0.00101
# Cumulative Proportion  0.97453 0.97572 0.97688 0.97801 0.97909 0.98013 0.98114
#                           PC64    PC65    PC66    PC67    PC68    PC69    PC70
# Standard deviation     1.50305 1.49857 1.47479 1.43009 1.40688 1.38528 1.34510
# Proportion of Variance 0.00098 0.00097 0.00094 0.00089 0.00086 0.00083 0.00079
# Cumulative Proportion  0.98212 0.98309 0.98404 0.98492 0.98578 0.98662 0.98740
#                           PC71    PC72    PC73    PC74    PC75    PC76   PC77
# Standard deviation     1.33213 1.28857 1.27955 1.24376 1.21546 1.19958 1.1748
# Proportion of Variance 0.00077 0.00072 0.00071 0.00067 0.00064 0.00062 0.0006
# Cumulative Proportion  0.98817 0.98889 0.98960 0.99027 0.99092 0.99154 0.9921
#                           PC78    PC79    PC80    PC81   PC82    PC83    PC84
# Standard deviation     1.15785 1.15023 1.12774 1.09613 1.0753 1.06727 1.02723
# Proportion of Variance 0.00058 0.00057 0.00055 0.00052 0.0005 0.00049 0.00046
# Cumulative Proportion  0.99272 0.99330 0.99385 0.99437 0.9949 0.99537 0.99582
#                           PC85    PC86   PC87    PC88    PC89    PC90    PC91
# Standard deviation     1.00916 0.97409 0.9611 0.93945 0.91372 0.88748 0.88256
# Proportion of Variance 0.00044 0.00041 0.0004 0.00038 0.00036 0.00034 0.00034
# Cumulative Proportion  0.99627 0.99668 0.9971 0.99746 0.99782 0.99817 0.99850
#                           PC92    PC93    PC94    PC95    PC96    PC97   PC98
# Standard deviation     0.86484 0.80178 0.73475 0.63987 0.59554 0.54030 0.4900
# Proportion of Variance 0.00032 0.00028 0.00023 0.00018 0.00015 0.00013 0.0001
# Cumulative Proportion  0.99883 0.99911 0.99934 0.99952 0.99967 0.99980 0.9999
#                          PC99     PC100
# Standard deviation     0.4707 1.621e-14
# Proportion of Variance 0.0001 0.000e+00
# Cumulative Proportion  1.0000 1.000e+00

# %%
n <- 30
par(mfrow = c(2,2))
#Hacemos la reconstruccion utilizando i valores propios  vectores propios
for (i in seq(10,70,20)){
    m <- svds$x[, 1:i] %*% t(svds$rotation[, 1:i])
    ipca <- matToImage(m)
    image(ipca,col=gray((0:255)/255))
}
# Out:
# plot without title

# %% [markdown]
# ### 3.3 ¿Cómo influye el valor de k en la calidad de la reconstruccion?

# %% [markdown]
# ## 4. Segmentación usando spectral clustering

# %%
# Creamos un grafo donde cada nodo es un dato. 
img<-readJPEG("dogSmall.jpg")
imgGray<-0.3*img[,,1]+0.59*img[,,2]+0.11*img[,,3]
imgGray <- t(apply(imgGray, 2, rev))
data<-as.vector(imgGray)
# #Definimos wij como la similitud entre el nodo i y el nodo j. 
k<-kernelMatrix(rbfdot(sigma = sd(data)),data)

# En el grafo solo vamos a conectar los grafos con similitud alta
getAdjMat<-function(k, nneighbors){
    n<-nrow(k)
    adjMat <- matrix(rep(0,n^2), ncol=n)
    for(i in 1:n) {
      nearestNodes <- sort(k[i,], decreasing=TRUE)[1:nneighbors]
      for (s in nearestNodes) {
        j <- which(k[i,] == s)
        adjMat[i,j] <- k[i,j]
        adjMat[j,i] <- k[i,j] 
      }
    }
  return(adjMat)   
}

#Matriz de adyacencia
W<-getAdjMat(k, 10)
# Matriz diagonal
D<-diag(apply(W, 1, sum))

#Laplaciano normalizado
L <-D-W
eig<-eigen(L)
Z   <- eig$vectors[,nrow(k)-1]
ncentroids<-2
km <- kmeans(Z, centers=ncentroids)
centerValM<-matrix(km$cluster-1, nrow(imgGray), ncol(imgGray))
image(centerValM,col=gray((0:255)/255))
# Out:
# plot without title
